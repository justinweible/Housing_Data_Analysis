# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from statsmodels.formula.api import ols
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('data/kc_house_data.csv')
corr=df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
df=df[['price','sqft_living','bedrooms','bathrooms','floors','grade','condition','yr_built','yr_renovated','waterfront']]
df
# Out:
#           price  sqft_living  bedrooms  bathrooms  floors  grade  condition  \
# 0      221900.0         1180         3       1.00     1.0      7          3
# 1      538000.0         2570         3       2.25     2.0      7          3
# 2      180000.0          770         2       1.00     1.0      6          3
# 3      604000.0         1960         4       3.00     1.0      7          5
# 4      510000.0         1680         3       2.00     1.0      8          3
# ...         ...          ...       ...        ...     ...    ...        ...
# 21592  360000.0         1530         3       2.50     3.0      8          3
# 21593  400000.0         2310         4       2.50     2.0      8          3
# 21594  402101.0         1020         2       0.75     2.0      7          3
# 21595  400000.0         1600         3       2.50     2.0      8          3
# 21596  325000.0         1020         2       0.75     2.0      7          3
#
#        yr_built  yr_renovated  waterfront
# 0          1955           0.0         NaN
# 1          1951        1991.0         0.0
# 2          1933           NaN         0.0
# 3          1965           0.0         0.0
# 4          1987           0.0         0.0
# ...         ...           ...         ...
# 21592      2009           0.0         0.0
# 21593      2014           0.0         0.0
# 21594      2009           0.0         0.0
# 21595      2004           0.0         NaN
# 21596      2008           0.0         0.0
#
# [21597 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# price              0
# sqft_living        0
# bedrooms           0
# bathrooms          0
# floors             0
# grade              0
# condition          0
# yr_built           0
# yr_renovated    3842
# waterfront      2376
# dtype: int64

# %%
df['waterfront'] = df['waterfront'].fillna(0)

# %%
df.isnull().sum()
df['yr_renovated'] = df['yr_renovated'].fillna(0)
df.isnull().sum()
# Out:
# price           0
# sqft_living     0
# bedrooms        0
# bathrooms       0
# floors          0
# grade           0
# condition       0
# yr_built        0
# yr_renovated    0
# waterfront      0
# dtype: int64

# %%
df.rename(columns={'yr_renovated': 'renovated'}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        21597 non-null  float64
#  1   sqft_living  21597 non-null  int64
#  2   bedrooms     21597 non-null  int64
#  3   bathrooms    21597 non-null  float64
#  4   floors       21597 non-null  float64
#  5   grade        21597 non-null  int64
#  6   condition    21597 non-null  int64
#  7   yr_built     21597 non-null  int64
#  8   renovated    21597 non-null  float64
#  9   waterfront   21597 non-null  float64
# dtypes: float64(5), int64(5)
# memory usage: 1.6 MB

# %%
df['age'] = 2015 - df.yr_built
df = df.drop(columns=['yr_built'], axis=1)

# %%
renovated = df.renovated.values
age = df.age.values
values = np.where(renovated <= 10, 1, 0)
df['renovated'] = np.where(age <= 5, 1, values)

# %%
df.head()
# Out:
#       price  sqft_living  bedrooms  bathrooms  floors  grade  condition  \
# 0  221900.0         1180         3       1.00     1.0      7          3
# 1  538000.0         2570         3       2.25     2.0      7          3
# 2  180000.0          770         2       1.00     1.0      6          3
# 3  604000.0         1960         4       3.00     1.0      7          5
# 4  510000.0         1680         3       2.00     1.0      8          3
#
#    renovated  waterfront  age
# 0          1         0.0   60
# 1          0         0.0   64
# 2          1         0.0   82
# 3          1         0.0   50
# 4          1         0.0   28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        21597 non-null  float64
#  1   sqft_living  21597 non-null  int64
#  2   bedrooms     21597 non-null  int64
#  3   bathrooms    21597 non-null  float64
#  4   floors       21597 non-null  float64
#  5   grade        21597 non-null  int64
#  6   condition    21597 non-null  int64
#  7   renovated    21597 non-null  int32
#  8   waterfront   21597 non-null  float64
#  9   age          21597 non-null  int64
# dtypes: float64(4), int32(1), int64(5)
# memory usage: 1.6 MB

# %%
df[['bedrooms', 'bathrooms', 'floors', 'age','renovated','grade','waterfront','sqft_living']].hist(figsize  = [6, 6]);

# %%
ax = sns.boxplot(x="price", data=df)

# %%
plt.scatter(df['bedrooms'], df['price'], color='green')
plt.title('Bedrooms and Price', fontsize=14)
plt.xlabel('Number of Bedrooms', fontsize=14)
plt.ylabel('House Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
sns.jointplot(data=df, x="bedrooms", y="price", kind="reg")

# %%
sns.jointplot(data=df, x="grade", y="price", kind="reg")

# %%
sns.jointplot(data=df, x="bathrooms", y="price", kind="reg")

# %%
sns.jointplot(data=df, x="floors", y="price", kind="reg")

# %%
sns.jointplot(data=df, x="age", y="price", kind="reg")

# %%
sns.jointplot(data=df, x="renovated", y="price", kind="reg")

# %%
plt.scatter(df['bathrooms'], df['price'], color='blue')
plt.title('Bathrooms and Price', fontsize=14)
plt.xlabel('Number of Bathrooms', fontsize=14)
plt.ylabel('House Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['floors'], df['price'], color='red')
plt.title('Floors and Price', fontsize=14)
plt.xlabel('Number of Floors', fontsize=14)
plt.ylabel('House Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['age'], df['price'], color='orange')
plt.title('House Age and Price', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.ylabel('House Price', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Model 1

# %%
def tts_model(df):
    y = df['price']
    X = df.drop(columns=['price'], axis=1)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state=123)
    
    linreg = LinearRegression()
    model = linreg.fit(X_train, y_train)

    train_predictions = model.predict(X_train)
    test_predictions = model.predict(X_test)

    mse_train = mean_squared_error(y_train, train_predictions)
    mse_test = mean_squared_error(y_test, test_predictions)
    
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)

    print('Mean Squared Error Test:', np.sqrt(mse_test))
    print('Mean Squared Error Train:', np.sqrt(mse_train))
    print('Training Score:', round(train_score, 2))
    print('Test Score:', round(test_score, 2))
    print('Coefficients:', model.coef_)

    X_train = sm.add_constant(X_train)
    smmodel = sm.OLS(y_train, X_train).fit()
    print(smmodel.summary())
    return smmodel

# %%
model = tts_model(df)
# Out:
# Mean Squared Error Test: 223337.89593381085
# Mean Squared Error Train: 217790.18979912275
# Training Score: 0.65
# Test Score: 0.64
# Coefficients: [ 1.70862728e+02 -3.90434399e+04  5.01146020e+04  2.16257723e+04
#   1.30549541e+05  1.96221012e+04 -2.41839672e+04  8.13062944e+05
#   3.76456089e+03]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.647
# Model:                            OLS   Adj. R-squared:                  0.647
# Method:                 Least Squares   F-statistic:                     3523.
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):               0.00
# Time:                        12:27:22   Log-Likelihood:            -2.3687e+05
# No. Observations:               17277   AIC:                         4.738e+05
# Df Residuals:                   17267   BIC:                         4.738e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.036e+06   2.18e+04    -47.598      0.000   -1.08e+06   -9.93e+05
# sqft_living   170.8627      3.631     47.062      0.000     163.746     177.979
# bedrooms    -3.904e+04   2263.580    -17.249      0.000   -4.35e+04   -3.46e+04
# bathrooms    5.011e+04   3883.317     12.905      0.000    4.25e+04    5.77e+04
# floors       2.163e+04   3829.938      5.647      0.000    1.41e+04    2.91e+04
# grade        1.305e+05   2401.955     54.351      0.000    1.26e+05    1.35e+05
# condition    1.962e+04   2786.018      7.043      0.000    1.42e+04    2.51e+04
# renovated   -2.418e+04   9387.968     -2.576      0.010   -4.26e+04   -5782.598
# waterfront   8.131e+05    2.1e+04     38.685      0.000    7.72e+05    8.54e+05
# age          3764.5609     77.828     48.370      0.000    3612.009    3917.112
# ==============================================================================
# Omnibus:                    12126.574   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           665525.651
# Skew:                           2.781   Prob(JB):                         0.00
# Kurtosis:                      32.893   Cond. No.                     3.06e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.06e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.figure(figsize=(12, 8))
fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True)
plt.title('QQ Plot')
plt.tight_layout()

# %%
plt.figure(figsize=(12, 8))
sns.distplot(df.price)
plt.title('Price Distribution')
plt.tight_layout()

# %%
df = df[df['price'] <= 1000000]

# %%
plt.figure(figsize=(12, 8))
sns.distplot(df.price)
plt.title('Price Distribution')
plt.tight_layout()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20139 entries, 0 to 21596
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        20139 non-null  float64
#  1   sqft_living  20139 non-null  int64
#  2   bedrooms     20139 non-null  int64
#  3   bathrooms    20139 non-null  float64
#  4   floors       20139 non-null  float64
#  5   grade        20139 non-null  int64
#  6   condition    20139 non-null  int64
#  7   renovated    20139 non-null  int32
#  8   waterfront   20139 non-null  float64
#  9   age          20139 non-null  int64
# dtypes: float64(4), int32(1), int64(5)
# memory usage: 1.6 MB

# %%
model = tts_model(df)
# Out:
# Mean Squared Error Test: 133107.73512640718
# Mean Squared Error Train: 132433.03536981763
# Training Score: 0.55
# Test Score: 0.54
# Coefficients: [ 8.43838281e+01 -1.41137329e+04  2.85594084e+04  3.72778990e+04
#   9.85106851e+04  1.69783077e+04 -4.95624714e+03  1.44258954e+05
#   2.58940538e+03]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.545
# Model:                            OLS   Adj. R-squared:                  0.545
# Method:                 Least Squares   F-statistic:                     2143.
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):               0.00
# Time:                        12:27:23   Log-Likelihood:            -2.1287e+05
# No. Observations:               16111   AIC:                         4.258e+05
# Df Residuals:                   16101   BIC:                         4.258e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        -6.71e+05   1.45e+04    -46.246      0.000   -6.99e+05   -6.43e+05
# sqft_living    84.3838      2.501     33.735      0.000      79.481      89.287
# bedrooms    -1.411e+04   1457.200     -9.686      0.000    -1.7e+04   -1.13e+04
# bathrooms    2.856e+04   2511.153     11.373      0.000    2.36e+04    3.35e+04
# floors       3.728e+04   2443.269     15.257      0.000    3.25e+04    4.21e+04
# grade        9.851e+04   1591.026     61.916      0.000    9.54e+04    1.02e+05
# condition    1.698e+04   1770.711      9.588      0.000    1.35e+04    2.04e+04
# renovated   -4956.2471   6376.139     -0.777      0.437   -1.75e+04    7541.695
# waterfront   1.443e+05   2.25e+04      6.421      0.000       1e+05    1.88e+05
# age          2589.4054     50.737     51.036      0.000    2489.955    2688.856
# ==============================================================================
# Omnibus:                      424.282   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              512.263
# Skew:                           0.344   Prob(JB):                    5.80e-112
# Kurtosis:                       3.539   Cond. No.                     4.52e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.52e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True)
plt.title('QQ Plot')
plt.show()

# %% [markdown]
# ## Multicollinearity

# %%
X = df.drop(columns=['price'], axis=1)
plt.figure(figsize=(14, 10))
sns.heatmap(X.corr(), center=0)
plt.tight_layout()
plt.show()

# %%
abs(X.corr()) >= .7
# Out:
#              sqft_living  bedrooms  bathrooms  floors  grade  condition  \
# sqft_living         True     False       True   False  False      False
# bedrooms           False      True      False   False  False      False
# bathrooms           True     False       True   False  False      False
# floors             False     False      False    True  False      False
# grade              False     False      False   False   True      False
# condition          False     False      False   False  False       True
# renovated          False     False      False   False  False      False
# waterfront         False     False      False   False  False      False
# age                False     False      False   False  False      False
#
#              renovated  waterfront    age
# sqft_living      False       False  False
# bedrooms         False       False  False
# bathrooms        False       False  False
# floors           False       False  False
# grade            False       False  False
# condition        False       False  False
# renovated         True       False  False
# waterfront       False        True  False
# age              False       False   True

# %%
corr_df = X.corr().abs().stack().reset_index().sort_values(0, ascending=False)

# Zip the variable name columns in a  column named "pairs"
corr_df['pairs'] = list(zip(corr_df.level_0, corr_df.level_1))

# Set index to pairs
corr_df.set_index(['pairs'], inplace = True)

# Drop level columns
corr_df.drop(columns=['level_1', 'level_0'], inplace = True)

# Rename correlation column to cc
corr_df.columns = ['cc']

# Drop duplicates
corr_df.drop_duplicates(inplace=True)

# %%
corr_df[(corr_df.cc>.70) & (corr_df.cc <1)]
# Out:
#                                 cc
# pairs
# (sqft_living, bathrooms)  0.711427

# %%
X = sm.add_constant(X)
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_dict = dict(zip(X.columns, vif))
vif_dict
# Out:
# {'const': 194.75647956388343,
#  'sqft_living': 3.284665457600202,
#  'bedrooms': 1.6320555894183715,
#  'bathrooms': 2.860860506717479,
#  'floors': 1.5944834560572103,
#  'grade': 2.384862189192804,
#  'condition': 1.197789108150541,
#  'renovated': 1.0951335809856484,
#  'waterfront': 1.004808919261464,
#  'age': 2.0058228821710773}

# %%
tts_model(df)
# Out:
# Mean Squared Error Test: 133107.73512640718
# Mean Squared Error Train: 132433.03536981763
# Training Score: 0.55
# Test Score: 0.54
# Coefficients: [ 8.43838281e+01 -1.41137329e+04  2.85594084e+04  3.72778990e+04
#   9.85106851e+04  1.69783077e+04 -4.95624714e+03  1.44258954e+05
#   2.58940538e+03]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.545
# Model:                            OLS   Adj. R-squared:                  0.545
# Method:                 Least Squares   F-statistic:                     2143.
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):               0.00
# Time:                        12:27:24   Log-Likelihood:            -2.1287e+05
# No. Observations:               16111   AIC:                         4.258e+05
# Df Residuals:                   16101   BIC:                         4.258e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        -6.71e+05   1.45e+04    -46.246      0.000   -6.99e+05   -6.43e+05
# sqft_living    84.3838      2.501     33.735      0.000      79.481      89.287
# bedrooms    -1.411e+04   1457.200     -9.686      0.000    -1.7e+04   -1.13e+04
# bathrooms    2.856e+04   2511.153     11.373      0.000    2.36e+04    3.35e+04
# floors       3.728e+04   2443.269     15.257      0.000    3.25e+04    4.21e+04
# grade        9.851e+04   1591.026     61.916      0.000    9.54e+04    1.02e+05
# condition    1.698e+04   1770.711      9.588      0.000    1.35e+04    2.04e+04
# renovated   -4956.2471   6376.139     -0.777      0.437   -1.75e+04    7541.695
# waterfront   1.443e+05   2.25e+04      6.421      0.000       1e+05    1.88e+05
# age          2589.4054     50.737     51.036      0.000    2489.955    2688.856
# ==============================================================================
# Omnibus:                      424.282   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              512.263
# Skew:                           0.344   Prob(JB):                    5.80e-112
# Kurtosis:                       3.539   Cond. No.                     4.52e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.52e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df = df.drop(columns=['renovated'], axis=1)

# %%
tts_model(df)
# Out:
# Mean Squared Error Test: 133097.8378607575
# Mean Squared Error Train: 132435.52021768864
# Training Score: 0.55
# Test Score: 0.54
# Coefficients: [ 8.43816530e+01 -1.41516678e+04  2.87929921e+04  3.73619606e+04
#   9.85266464e+04  1.67869111e+04  1.45053655e+05  2.60060565e+03]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.545
# Model:                            OLS   Adj. R-squared:                  0.545
# Method:                 Least Squares   F-statistic:                     2411.
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):               0.00
# Time:                        12:27:24   Log-Likelihood:            -2.1287e+05
# No. Observations:               16111   AIC:                         4.258e+05
# Df Residuals:                   16102   BIC:                         4.258e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -6.762e+05   1.28e+04    -52.635      0.000   -7.01e+05   -6.51e+05
# sqft_living    84.3817      2.501     33.734      0.000      79.479      89.285
# bedrooms    -1.415e+04   1456.365     -9.717      0.000    -1.7e+04   -1.13e+04
# bathrooms    2.879e+04   2493.078     11.549      0.000    2.39e+04    3.37e+04
# floors       3.736e+04   2440.844     15.307      0.000    3.26e+04    4.21e+04
# grade        9.853e+04   1590.874     61.932      0.000    9.54e+04    1.02e+05
# condition    1.679e+04   1753.486      9.573      0.000    1.33e+04    2.02e+04
# waterfront   1.451e+05   2.24e+04      6.463      0.000    1.01e+05    1.89e+05
# age          2600.6057     48.647     53.458      0.000    2505.251    2695.960
# ==============================================================================
# Omnibus:                      425.663   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              514.232
# Skew:                           0.344   Prob(JB):                    2.17e-112
# Kurtosis:                       3.540   Cond. No.                     4.52e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.52e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True)
plt.title('QQ Plot')
plt.show()

# %%
#View distribution plots for all columns
for col in df.columns:
    plt.subplots(1, 1)
    sns.distplot(df[col])

# %%
X = df.drop(columns=['price'], axis=1)
y = df.price

#Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state=123)

#Fit the model
linreg = LinearRegression()
model = linreg.fit(X_train, y_train)
model

#View model accuracy
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)
train_preds = model.predict(X_train)
test_preds = model.predict(X_test)

print('Training Score:', round(train_score, 2))
print('Test Score:', round(test_score, 2))
print('Intercept:', model.intercept_)
print('Coefficients:', model.coef_)

#View model summary in statsmodels
X_train = sm.add_constant(X_train)
smmodel = sm.OLS(y_train, X_train).fit()
smmodel.summary()
# Out:
# Training Score: 0.55
# Test Score: 0.54
# Intercept: -676205.8554276901
# Coefficients: [ 8.43816530e+01 -1.41516678e+04  2.87929921e+04  3.73619606e+04
#   9.85266464e+04  1.67869111e+04  1.45053655e+05  2.60060565e+03]
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.545
# Model:                            OLS   Adj. R-squared:                  0.545
# Method:                 Least Squares   F-statistic:                     2411.
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):               0.00
# Time:                        12:28:55   Log-Likelihood:            -2.1287e+05
# No. Observations:               16111   AIC:                         4.258e+05
# Df Residuals:                   16102   BIC:                         4.258e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -6.762e+05   1.28e+04    -52.635      0.000   -7.01e+05   -6.51e+05
# sqft_living    84.3817      2.501     33.734      0.000      79.479      89.285
# bedrooms    -1.415e+04   1456.365     -9.717      0.000    -1.7e+04   -1.13e+04
# bathrooms    2.879e+04   2493.078     11.549      0.000    2.39e+04    3.37e+04
# floors       3.736e+04   2440.844     15.307      0.000    3.26e+04    4.21e+04
# grade        9.853e+04   1590.874     61.932      0.000    9.54e+04    1.02e+05
# condition    1.679e+04   1753.486      9.573      0.000    1.33e+04    2.02e+04
# waterfront   1.451e+05   2.24e+04      6.463      0.000    1.01e+05    1.89e+05
# age          2600.6057     48.647     53.458      0.000    2505.251    2695.960
# ==============================================================================
# Omnibus:                      425.663   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              514.232
# Skew:                           0.344   Prob(JB):                    2.17e-112
# Kurtosis:                       3.540   Cond. No.                     4.52e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.52e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.figure(figsize=(12, 8))
plt.scatter(train_preds, smmodel.resid)
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Checking for Homoscedasticity')
plt.show()
